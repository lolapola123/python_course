# %%
import requests
import json

# %%
token="EAAK5vjeNNTABAOPPUkeoAZAFU7IIdD3yCcwirJZCk8JcggMaqFZCQ8kuTCoc9Rb2wfrmzM0FkpFvZBNXHvXr49zjjUpn1X3KCo9KOLiKn1GAEsZCch24wuhhdNHcH1Kv4eUNfOnTP3wlbMYZBZABheZAzaHg2QOsQiKTzIwV9R4j4rUjoO5YNDIf4r3yQN7CZAKeu8TxQ4hGCoQZDZD"
query=input("enter your query")
url=f"https://graph.facebook.com/v3.3/me?fields={query}&access_token={token}"
page=requests.get(url)
print(page)
if page.status_code == 200 :
    data=page.json()
    print(page.content)
    print(page.content)
    for key,value in data.items():
        f"key={key} value = {value}"
else :
    print("something went wrong")
# Out:
# enter your query
# <Response [200]>
# b'{"name":"Rachit Dhar","id":"2523204027710751"}'
# b'{"name":"Rachit Dhar","id":"2523204027710751"}'

# %%
page.status_code
# Out:
# 200

# %%
url="https://images.pexels.com/photos/67636/rose-blue-flower-rose-blooms-67636.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500"
page=requests.get(url)

# %%
page.status_code
# Out:
# 200

# %%
page.content[:10]
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF'

# %%
f=open("myimg.jpeg","wb")
f.write(page.content)
f.close()

# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img=plt.imread("myimg.jpeg")
print(img.shape)
plt.imshow(img)
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# (331, 500, 3)

# %%
def download(url,filename):
    img=plt.imread("myimg.jpeg")
    print(img.shape)
    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])
    plt.show()
list["https://files.realpython.com/media/python-modules-packages-title.e61993fd2eb4.jpg","https://images.pexels.com/photos/67636/rose-blue-flower-rose-blooms-67636.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500"]
for i in range(2):

    download(list[i],"sss")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-ec9f8068a56e> in <module>
#       6     plt.yticks([])
#       7     plt.show()
# ----> 8 list["https://files.realpython.com/media/python-modules-packages-title.e61993fd2eb4.jpg","https://images.pexels.com/photos/67636/rose-blue-flower-rose-blooms-67636.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500"]
#       9 for i in range(2):
#      10
#
# TypeError: 'type' object is not subscriptable

# %%
page=requests.get("https://grras.com")
page.status_code
# Out:
# 200

# %%
page.headers["Content-Type"]
# Out:
# 'text/html; charset=UTF-8'

# %%
page.content[:100]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a2cb8e03294c> in <module>
# ----> 1 page.content[:100]
#
# NameError: name 'page' is not defined

# %%
fp=open("C:/Users/Rachit/grras.html","wb")
fp.write(page.content)
fp.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-05850ff258cc> in <module>
#       1 fp=open("C:/Users/Rachit/grras.html","wb")
# ----> 2 fp.write(page.content)
#       3 fp.close()
#
# NameError: name 'page' is not defined

# %%
import bs4

# %%
page.content[:20]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-48adf13f87b7> in <module>
# ----> 1 page.content[:20]
#
# NameError: name 'page' is not defined

# %%
soup = bs4.BeautifulSoup(page.text,"html")

# %%
soup.find_all(img)
